# %% [markdown]
# # Deep Learning and Neural Network - Question 4
# ## Arian Firoozi - 810100196
# ## Arman Majidi - 810100205
#
# ![University of Tehran logo](UTLogo\University_of_Tehran_logo.svg "University of Tehran")
# ![Engineering faculty of University of Tehran logo](UTLogo\Engineering_faculty_University_of_Tehran_logo.png "Engineering faculty")
#
# # Outline
# - [ 0 - Packages ](#0)
# - [ 1 - Reading Data](#1)
# - [ 2 - Correlation Matrix ](#2)
# - [ 3 - Distribution of Prices ](#3)
# - [ 4 - Preprocessing ](#4)
# - [ 5 - Model Design](#5)
# - [ 6 - Training](#6)

# %% [markdown]
# <a name="0"></a>
# ## Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# <a name="1"></a>
# ## 4.1 Reading Data

# %%
data = pd.read_csv("data/Question4.csv")

# %%
for col in data.head():
    print(f"Nan values in {col}:", sum(1 if pd.isnull(data[col][i]) else 0 for i in range(data[col].size)))
# Out:
# Nan values in id: 0
# Nan values in date: 0
# Nan values in price: 0
# Nan values in bedrooms: 0
# Nan values in bathrooms: 0
# Nan values in sqft_living: 0
# Nan values in sqft_lot: 0
# Nan values in floors: 0
# Nan values in waterfront: 0
# Nan values in view: 0
# Nan values in condition: 0
# Nan values in grade: 0
# Nan values in sqft_above: 0
# Nan values in sqft_basement: 0
# Nan values in yr_built: 0
# Nan values in yr_renovated: 0
# Nan values in zipcode: 0
# Nan values in lat: 0
# Nan values in long: 0
# Nan values in sqft_living15: 0
# Nan values in sqft_lot15: 0

# %% [markdown]
# <a name="2"></a>
# ## 4.2 Correlation Matrix

# %%
c=data.corr(numeric_only=True)
c.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_d4a5c_row0_col0, #T_d4a5c_row1_col1, #T_d4a5c_row2_col2, #T_d4a5c_row3_col3, #T_d4a5c_row4_col4, #T_d4a5c_row5_col5, #T_d4a5c_row6_col6, #T_d4a5c_row7_col7, #T_d4a5c_row8_col8, #T_d4a5c_row9_col9, #T_d4a5c_row10_col10, #T_d4a5c_row11_col11, #T_d4a5c_row12_col12, #T_d4a5c_row13_col13, #T_d4a5c_row14_col14, #T_d4a5c_row15_col15, #T_d4a5c_row16_col16, #T_d4a5c_row17_col17, #T_d4a5c_row18_col18, #T_d4a5c_row19_col19 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_d4a5c_row0_col1, #T_d4a5c_row2_col7, #T_d4a5c_row9_col10 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_d4a5c_row0_col2, #T_d4a5c_row5_col1, #T_d4a5c_row7_col5, #T_d4a5c_row8_col16, #T_d4a5c_row9_col14, #T_d4a5c_row14_col19 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_d4a5c_row0_col3, #T_d4a5c_row3_col9, #T_d4a5c_row4_col16, #T_d4a5c_row6_col16 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_d4a5c_row0_col4, #T_d4a5c_row2_col19, #T_d4a5c_row7_col19, #T_d4a5c_row11_col12, #T_d4a5c_row14_col16 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_d4a5c_row0_col5, #T_d4a5c_row6_col12, #T_d4a5c_row9_col6, #T_d4a5c_row9_col13, #T_d4a5c_row13_col9, #T_d4a5c_row13_col14, #T_d4a5c_row13_col16, #T_d4a5c_row15_col1, #T_d4a5c_row15_col2, #T_d4a5c_row15_col3, #T_d4a5c_row15_col4, #T_d4a5c_row15_col5, #T_d4a5c_row15_col10, #T_d4a5c_row15_col11, #T_d4a5c_row15_col17, #T_d4a5c_row15_col18, #T_d4a5c_row15_col19, #T_d4a5c_row17_col7, #T_d4a5c_row17_col8, #T_d4a5c_row17_col15, #T_d4a5c_row19_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_d4a5c_row0_col6, #T_d4a5c_row3_col14, #T_d4a5c_row7_col10, #T_d4a5c_row8_col13, #T_d4a5c_row12_col16, #T_d4a5c_row14_col11 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_d4a5c_row0_col7 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_d4a5c_row0_col8, #T_d4a5c_row9_col1 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_d4a5c_row0_col9, #T_d4a5c_row3_col8, #T_d4a5c_row7_col13, #T_d4a5c_row16_col6 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_d4a5c_row0_col10, #T_d4a5c_row13_col5, #T_d4a5c_row15_col6 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_d4a5c_row0_col11, #T_d4a5c_row1_col5, #T_d4a5c_row2_col14, #T_d4a5c_row10_col14, #T_d4a5c_row18_col9 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_d4a5c_row0_col12, #T_d4a5c_row3_col5, #T_d4a5c_row8_col19, #T_d4a5c_row11_col15 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_d4a5c_row0_col13, #T_d4a5c_row5_col15, #T_d4a5c_row7_col9, #T_d4a5c_row11_col5 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_d4a5c_row0_col14, #T_d4a5c_row14_col1, #T_d4a5c_row14_col8, #T_d4a5c_row14_col10, #T_d4a5c_row18_col16 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_d4a5c_row0_col15, #T_d4a5c_row5_col11, #T_d4a5c_row17_col3 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_d4a5c_row0_col16, #T_d4a5c_row3_col0, #T_d4a5c_row7_col2, #T_d4a5c_row9_col19, #T_d4a5c_row11_col16, #T_d4a5c_row17_col14, #T_d4a5c_row19_col1 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_d4a5c_row0_col17, #T_d4a5c_row1_col17, #T_d4a5c_row12_col18 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_d4a5c_row0_col18, #T_d4a5c_row10_col5, #T_d4a5c_row14_col18 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_d4a5c_row0_col19, #T_d4a5c_row5_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_d4a5c_row1_col0, #T_d4a5c_row9_col5, #T_d4a5c_row14_col0 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_d4a5c_row1_col2, #T_d4a5c_row14_col15 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_d4a5c_row1_col3, #T_d4a5c_row18_col1 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_d4a5c_row1_col4, #T_d4a5c_row3_col11, #T_d4a5c_row19_col5 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_d4a5c_row1_col6 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_d4a5c_row1_col7, #T_d4a5c_row6_col1 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_d4a5c_row1_col8, #T_d4a5c_row2_col12, #T_d4a5c_row6_col17 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_d4a5c_row1_col9, #T_d4a5c_row9_col17 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_d4a5c_row1_col10, #T_d4a5c_row10_col3 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_d4a5c_row1_col11, #T_d4a5c_row10_col1 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_d4a5c_row1_col12, #T_d4a5c_row2_col10 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_d4a5c_row1_col13, #T_d4a5c_row10_col8, #T_d4a5c_row17_col6 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_d4a5c_row1_col14, #T_d4a5c_row2_col9, #T_d4a5c_row4_col19, #T_d4a5c_row7_col18, #T_d4a5c_row16_col12, #T_d4a5c_row18_col19 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_d4a5c_row1_col15, #T_d4a5c_row8_col3 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_d4a5c_row1_col16, #T_d4a5c_row12_col2 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_d4a5c_row1_col18 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_d4a5c_row1_col19, #T_d4a5c_row8_col2, #T_d4a5c_row11_col14, #T_d4a5c_row19_col6 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_d4a5c_row2_col0, #T_d4a5c_row2_col16, #T_d4a5c_row14_col5, #T_d4a5c_row16_col2, #T_d4a5c_row18_col7 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_d4a5c_row2_col1, #T_d4a5c_row8_col11, #T_d4a5c_row16_col1 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_d4a5c_row2_col3 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_d4a5c_row2_col4 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_d4a5c_row2_col5, #T_d4a5c_row2_col8, #T_d4a5c_row9_col18 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_d4a5c_row2_col6 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_d4a5c_row2_col11, #T_d4a5c_row6_col3 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_d4a5c_row2_col13 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_d4a5c_row2_col15, #T_d4a5c_row7_col11, #T_d4a5c_row7_col12, #T_d4a5c_row19_col9 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_d4a5c_row2_col17, #T_d4a5c_row10_col2 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_d4a5c_row2_col18 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_d4a5c_row3_col1 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_d4a5c_row3_col2, #T_d4a5c_row11_col17 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_d4a5c_row3_col4, #T_d4a5c_row4_col3, #T_d4a5c_row11_col10 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_d4a5c_row3_col6 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_d4a5c_row3_col7, #T_d4a5c_row6_col8, #T_d4a5c_row9_col0, #T_d4a5c_row14_col13 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_d4a5c_row3_col10, #T_d4a5c_row4_col1 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_d4a5c_row3_col12 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_d4a5c_row3_col13 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_d4a5c_row3_col15, #T_d4a5c_row4_col14, #T_d4a5c_row7_col6, #T_d4a5c_row10_col16, #T_d4a5c_row11_col8 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_d4a5c_row3_col16, #T_d4a5c_row11_col9, #T_d4a5c_row14_col2, #T_d4a5c_row15_col8 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_d4a5c_row3_col17 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_d4a5c_row3_col18 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_d4a5c_row3_col19, #T_d4a5c_row5_col6, #T_d4a5c_row16_col11 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_d4a5c_row4_col0, #T_d4a5c_row6_col5, #T_d4a5c_row11_col0, #T_d4a5c_row11_col7 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_d4a5c_row4_col2 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_d4a5c_row4_col5, #T_d4a5c_row8_col14, #T_d4a5c_row12_col17, #T_d4a5c_row13_col2, #T_d4a5c_row15_col9, #T_d4a5c_row19_col15 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_d4a5c_row4_col6 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_d4a5c_row4_col7, #T_d4a5c_row6_col0, #T_d4a5c_row13_col15, #T_d4a5c_row17_col0, #T_d4a5c_row19_col8 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_d4a5c_row4_col8, #

# %% [markdown]
# <a name="3"></a>
# ## 4.3 Distribution of Prices

# %%
import seaborn as sb
plt.figure(figsize=(10, 6))
sb.histplot(data['price'], kde=True)
plt.title("Distribution of Prices")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
most_corr = data.corr(numeric_only=True)['price'].drop('price').idxmax()
plt.figure(figsize=(10, 6))
plt.scatter(data[most_corr], data['price'], color='blue')
plt.title(f"Price vs {most_corr}")
plt.xlabel(most_corr)
plt.ylabel("Price")
plt.grid(True)
plt.show()

# %% [markdown]
# <a name="4"></a>
# ## 4.4 Preprocessing

# %%
date=data['date']
year, month=[],[]
for d in date:
    year.append(d[:4])
    month.append(d[4:6])
data['year']=year
data['month']=month
data=data.drop('date', axis=1)

# %%
x_train, x_val, y_train, y_val = train_test_split(data.drop('price', axis=1), data['price'], test_size=0.25)
train_scaler=MinMaxScaler()
x_train = train_scaler.fit_transform(x_train)
val_scaler=MinMaxScaler()
x_val = val_scaler.fit_transform(x_val)

# %% [markdown]
# <a name="5"></a>
# ## 4.5 Model Design

# %%
def one_hidden_mlp():
    model = Sequential()
    model.add(Dense(60, activation='relu', input_shape=(x_train.shape[1],)))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse')
    return model

# %%
def two_hidden_mlp():
    model = Sequential()
    model.add(Dense(30, activation='relu', input_shape=(x_train.shape[1],)))
    model.add(Dense(30, activation='relu'))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse')
    return model

# %% [markdown]
# <a name="6"></a>
# ## 4.6 Training

# %%
model_one_hidden = one_hidden_mlp()
history_one_hidden = model_one_hidden.fit(x_train, y_train, epochs=150, validation_data=(x_val, y_val), verbose=0)

plt.plot(history_one_hidden.history['loss'], label='Train Loss')
plt.plot(history_one_hidden.history['val_loss'], label='Validation Loss')
plt.title('One Hidden Layer - Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss (MSE)')
plt.legend()
plt.grid(True)
# Out:
# c:\Users\arian\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model_two_hidden = two_hidden_mlp()
history_two_hidden = model_two_hidden.fit(x_train, y_train, epochs=50, validation_data=(x_val, y_val), verbose=0)

plt.plot(history_two_hidden.history['loss'], label='Train Loss')
plt.plot(history_two_hidden.history['val_loss'], label='Validation Loss')
plt.title('Two Hidden Layers - Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.show()
# Out:
# c:\Users\arian\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
indices = np.random.choice(range(x_val.shape[0]), 5, replace=False)

pred=model_two_hidden.predict(x_val[indices])
print(f"avg error is {np.mean((y_val.iloc[indices].values-pred))/np.mean(y_train)}%")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# avg error is 0.029359435141878335%
