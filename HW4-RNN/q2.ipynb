# %% [markdown]
# # Deep Learning and Neural Network - Question 2
# ## Arian Firoozi - 810100196
# ## Arman Majidi - 810100205
#
# # Outline
# - [ 0 - Packages ](#0)
# - [ 1 - Data Downloading ](#1)
# - [ 2 - Data Preperation ](#2)
# - [ 3 - Model Implementation ](#3)
# - [ 4 - ARIMA Model ](#4)

# %% [markdown]
# ---

# %% [markdown]
# <a name="0"></a>
# ## 0 - Packages

# %% [markdown]
# # First, let's run the cell below to import all the packages.
# - [numpy](https://numpy.org) is the fundamental package for working with matrices in Python.
# - [pandas](https://pandas.pydata.org) is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool, built on top of the Python programming language.
# - [matplotlib](http://matplotlib.org) is a famous library to plot graphs in Python.
# - [seaborn](https://seaborn.pydata.org) is a Python data visualization library based on matplotlib.
# - [tensorflow](https://tensorflow.org) is an end-to-end platform for machine learning.
# - [keras](https://keras.io) is a deep learning API written in Python and capable of running on top of either JAX, TensorFlow, or PyTorch.
# - [scikit-learn](https://scikit-learn.org) is a Python module for machine learning.
# - [yfinance](https://ranaroussi.github.io/yfinance/index.html) is an open-source tool that uses Yahoo’s publicly available APIs, and is intended for research and educational purposes.
# - [statmodels](https://www.statsmodels.org/stable) is a Python module that provides classes and functions for the estimation of many different statistical models.
# - [pmdarima](https://alkaline-ml.com/pmdarima) is a statistical library designed to fill the void in Python's time series analysis capabilities.

# %%
# !pip install yfinance pmdarima
# Out:
# Collecting yfinance
#   Downloading yfinance-0.2.50-py2.py3-none-any.whl.metadata (5.5 kB)
# Collecting pmdarima
#   Downloading pmdarima-2.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl.metadata (7.8 kB)
# Requirement already satisfied: pandas>=1.3.0 in /opt/conda/lib/python3.10/site-packages (from yfinance) (2.2.3)
# Requirement already satisfied: numpy>=1.16.5 in /opt/conda/lib/python3.10/site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in /opt/conda/lib/python3.10/site-packages (from yfinance) (2.32.3)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.11-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: lxml>=4.9.1 in /opt/conda/lib/python3.10/site-packages (from yfinance) (5.3.0)
# Requirement already satisfied: platformdirs>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from yfinance) (3.11.0)
# Requirement already satisfied: pytz>=2022.5 in /opt/conda/lib/python3.10/site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in /opt/conda/lib/python3.10/site-packages (from yfinance) (2.4.4)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-3.17.8.tar.gz (948 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.2/948.2 kB 13.1 MB/s eta 0:00:00
# done
# done
# done
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /opt/conda/lib/python3.10/site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /opt/conda/lib/python3.10/site-packages (from yfinance) (1.1)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/lib/python3.10/site-packages (from pmdarima) (1.4.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /opt/conda/lib/python3.10/site-packages (from pmdarima) (3.0.10)
# Requirement already satisfied: scikit-learn>=0.22 in /opt/conda/lib/python3.10/site-packages (from pmdarima) (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in /opt/conda/lib/python3.10/site-packages (from pmdarima) (1.14.1)
# Requirement already satisfied: statsmodels>=0.13.2 in /opt/conda/lib/python3.10/site-packages (from pmdarima) (0.14.2)
# Requirement already satisfied: urllib3 in /opt/conda/lib/python3.10/site-packages (from pmdarima) (1.26.18)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /opt/conda/lib/python3.10/site-packages (from pmdarima) (70.0.0)
# Requirement already satisfied: packaging>=17.1 in /opt/conda/lib/python3.10/site-packages (from pmdarima) (21.3)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in /opt/conda/lib/python3.10/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.10/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=17.1->pmdarima) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.31->yfinance) (2024.6.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.22->pmdarima) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in /opt/conda/lib/python3.10/site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.6)
# Downloading yfinance-0.2.50-py2.py3-none-any.whl (102 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 kB 5.3 MB/s eta 0:00:00
# Downloading pmdarima-2.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 56.1 MB/s eta 0:00:00
# Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Building wheels for collected packages: peewee
# done
#   Created wheel for peewee: filename=peewee-3.17.8-cp310-cp310-linux_x86_64.whl size=300752 sha256=6636899557211ff78574e96e019fd35c95f69a44acd3b53740bb919e8502ce8a
#   Stored in directory: /root/.cache/pip/wheels/75/79/e5/8838db0594cc6c587142fd2563356392ade6255c5930411069
# Successfully built peewee
# Installing collected packages: peewee, multitasking, yfinance, pmdarima
# Successfully installed multitasking-0.0.11 peewee-3.17.8 pmdarima-2.0.4 yfinance-0.2.50

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, LSTM, Bidirectional, Dense
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, mean_absolute_percentage_error
import yfinance as yf
from statsmodels.tsa.arima.model import ARIMA
from pmdarima import auto_arima

# %% [markdown]
# ---

# %% [markdown]
# <a name="1"></a>
# ## 1 - Data Downloading

# %%
data_name = 'data.csv'

# %%
CLF = yf.download("CL=F", start="2010-01-01", end=None)
CLF.reset_index(inplace=True)
CLF.columns = CLF.columns.get_level_values(0)
CLF.rename(columns={'Price': 'Date'}, inplace=True)
CLF.to_csv(data_name, index=False)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ---

# %% [markdown]
# <a name="2"></a>
# ## 2 - Data Preparation

# %%
df = pd.read_csv(data_name)
df
# Out:
#             Date  Adj Close      Close       High        Low       Open  \
# 0     2010-01-04  81.510002  81.510002  81.680000  79.629997  79.629997
# 1     2010-01-05  81.769997  81.769997  82.000000  80.949997  81.629997
# 2     2010-01-06  83.180000  83.180000  83.519997  80.849998  81.430000
# 3     2010-01-07  82.660004  82.660004  83.360001  82.260002  83.199997
# 4     2010-01-08  82.750000  82.750000  83.470001  81.800003  82.650002
# ...          ...        ...        ...        ...        ...        ...
# 3760  2024-12-13  71.290001  71.290001  71.419998  69.870003  70.059998
# 3761  2024-12-16  70.709999  70.709999  71.440002  70.370003  71.440002
# 3762  2024-12-17  70.080002  70.080002  70.919998  69.180000  70.610001
# 3763  2024-12-18  70.580002  70.580002  71.379997  69.989998  70.220001
# 3764  2024-12-19  71.099998  71.099998  71.260002  70.110001  70.139999
#
#       Volume
# 0     263542
# 1     258887
# 2     370059
# 3     246632
# 4     310377
# ...      ...
# 3760  230429
# 3761  204296
# 3762   99604
# 3763   99604
# 3764    6808
#
# [3765 rows x 7 columns]

# %% [markdown]
# ### ◆ Null Data and Random Data Removing

# %%
df.dropna(axis=0, how='any', inplace=True)
num_rows_to_delete = int(len(df) * 0.1)
rows_to_delete = df.sample(n=num_rows_to_delete, random_state=24).index
df.drop(rows_to_delete, inplace=True)
df
# Out:
#             Date  Adj Close      Close       High        Low       Open  \
# 0     2010-01-04  81.510002  81.510002  81.680000  79.629997  79.629997
# 1     2010-01-05  81.769997  81.769997  82.000000  80.949997  81.629997
# 2     2010-01-06  83.180000  83.180000  83.519997  80.849998  81.430000
# 4     2010-01-08  82.750000  82.750000  83.470001  81.800003  82.650002
# 5     2010-01-11  82.519997  82.519997  83.949997  81.959999  82.879997
# ...          ...        ...        ...        ...        ...        ...
# 3759  2024-12-12  70.019997  70.019997  70.720001  69.139999  70.430000
# 3761  2024-12-16  70.709999  70.709999  71.440002  70.370003  71.440002
# 3762  2024-12-17  70.080002  70.080002  70.919998  69.180000  70.610001
# 3763  2024-12-18  70.580002  70.580002  71.379997  69.989998  70.220001
# 3764  2024-12-19  71.099998  71.099998  71.260002  70.110001  70.139999
#
#       Volume
# 0     263542
# 1     258887
# 2     370059
# 4     310377
# 5     296304
# ...      ...
# 3759  326046
# 3761  204296
# 3762   99604
# 3763   99604
# 3764    6808
#
# [3389 rows x 7 columns]

# %% [markdown]
# ### ◆ Data Interpolation

# %%
df['Date'] = pd.to_datetime(df['Date'])
df = df.sort_values(by='Date')
df.set_index('Date', inplace=True)
full_date_range = pd.date_range(start=df.index.min(), end=df.index.max(), freq='D')
df_reindexed = df.reindex(full_date_range)
df_interpolated = df_reindexed.interpolate()
df_final = df_interpolated.reset_index()
df_final.rename(columns={'index': 'Date'}, inplace=True)
df_final
# Out:
#            Date  Adj Close      Close       High        Low       Open  \
# 0    2010-01-04  81.510002  81.510002  81.680000  79.629997  79.629997
# 1    2010-01-05  81.769997  81.769997  82.000000  80.949997  81.629997
# 2    2010-01-06  83.180000  83.180000  83.519997  80.849998  81.430000
# 3    2010-01-07  82.965000  82.965000  83.494999  81.325001  82.040001
# 4    2010-01-08  82.750000  82.750000  83.470001  81.800003  82.650002
# ...         ...        ...        ...        ...        ...        ...
# 5459 2024-12-15  70.537498  70.537498  71.260002  70.062502  71.187502
# 5460 2024-12-16  70.709999  70.709999  71.440002  70.370003  71.440002
# 5461 2024-12-17  70.080002  70.080002  70.919998  69.180000  70.610001
# 5462 2024-12-18  70.580002  70.580002  71.379997  69.989998  70.220001
# 5463 2024-12-19  71.099998  71.099998  71.260002  70.110001  70.139999
#
#         Volume
# 0     263542.0
# 1     258887.0
# 2     370059.0
# 3     340218.0
# 4     310377.0
# ...        ...
# 5459  234733.5
# 5460  204296.0
# 5461   99604.0
# 5462   99604.0
# 5463    6808.0
#
# [5464 rows x 7 columns]

# %% [markdown]
# ### ◆ Train-Test Split and Min-Max Normalization

# %% [markdown]
# #### Needed Functions

# %%
def create_windows(data, window_size=2, overlap=0.5):
    step = int(window_size * (1 - overlap))
    x, y = [], []
    for i in range(0, len(data) - window_size, step):
        x.append(data[i:i + window_size])
        y.append(data[i + window_size])
    return np.array(x), np.array(y)

# %%
def prepare_train_test(train_data, test_data, window_size=2, overlap=0.5):
    x_train, y_train = create_windows(train_data, window_size, overlap)
    x_test, y_test = create_windows(test_data, window_size, overlap)
    return x_train, y_train, x_test, y_test

# %% [markdown]
# #### Train-Test Split

# %%
data = np.array(df_final['Adj Close'])
data = np.abs(data)
ind = int(len(data) * 0.7)
train = data[:ind]
test = data[ind:]
x_train, y_train, x_test, y_test = prepare_train_test(train, test)

# %%
print(f'''x_train shape: {x_train.shape} and y_train shape: {y_train.shape}
x_test shape: {x_test.shape} and y_test shape: {y_test.shape}''')
# Out:
# x_train shape: (3822, 2) and y_train shape: (3822,)
# x_test shape: (1638, 2) and y_test shape: (1638,)

# %% [markdown]
# #### Min-Max Normalization

# %%
min = np.min(x_train, 0)
max = np.max(x_train, 0)
x_train = (x_train - min) / (max - min)
x_test = (x_test - min) / (max - min)

# %% [markdown]
# ### ◆ Histogram Plotting

# %%
plt.figure(figsize=(10, 6))
plt.hist(data, bins=30, color='skyblue', edgecolor='black')  # Adjust bins for granularity
plt.xlabel('Price (Adj Close)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.title('Price Distribution of Adj Close', fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
train_indices = np.arange(len(y_train))
test_indices = np.arange(len(y_train), len(y_train) + len(y_test))
plt.figure(figsize=(10, 6))
plt.plot(train_indices, y_train, label='train')
plt.plot(test_indices, y_test, label='test')
plt.title('Training and Testing data for CL=F Price')
plt.legend(loc='lower right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# <a name="3"></a>
# ## 3 - Model Implementation

# %% [markdown]
# ### ◆ Hyperparameters

# %%
input_shape = (x_train.shape[1], 1)
learning_rate = 0.001
batch_size = 100
gruOptimizer = Adam(learning_rate=learning_rate)
lstmOptimizer = Adam(learning_rate=learning_rate)
bilstmOptimizer = Adam(learning_rate=learning_rate)
epoches = 50
units = {
    'LSTM': 512,
    'GRU': 512,
    'Bi-LSTM': 1024
}
metrics = [keras.metrics.MeanAbsoluteError(), keras.metrics.RootMeanSquaredError(),
           keras.metrics.R2Score(), keras.metrics.MeanAbsolutePercentageError()]

# %% [markdown]
# ### ◆ GRU Model

# %%
gruModel = Sequential([
    GRU(units['GRU'], return_sequences=True, input_shape=input_shape),
    GRU(units['GRU'], return_sequences=False),
    Dense(25, activation='relu'),
    Dense(1)
    ])
gruModel.compile(optimizer=gruOptimizer, loss='mse', metrics=metrics)
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
gruModel.fit(x_train, y_train, batch_size=batch_size, epochs=epoches)
# Out:
# Epoch 1/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 4298.7061 - mean_absolute_error: 59.7733 - mean_absolute_percentage_error: 83.1027 - r2_score: -7.3723 - root_mean_squared_error: 65.0763
# Epoch 2/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 533.8409 - mean_absolute_error: 20.6775 - mean_absolute_percentage_error: 38.9134 - r2_score: -0.0256 - root_mean_squared_error: 23.1027
# Epoch 3/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 508.6112 - mean_absolute_error: 20.1111 - mean_absolute_percentage_error: 36.1807 - r2_score: -4.6939e-04 - root_mean_squared_error: 22.5474
# Epoch 4/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 527.1063 - mean_absolute_error: 20.5238 - mean_absolute_percentage_error: 38.0711 - r2_score: 7.1865e-04 - root_mean_squared_error: 22.9585
# Epoch 5/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 519.0955 - mean_absolute_error: 20.3299 - mean_absolute_percentage_error: 39.1566 - r2_score: 0.0042 - root_mean_squared_error: 22.7816
# Epoch 6/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 507.6730 - mean_absolute_error: 20.1090 - mean_absolute_percentage_error: 39.8653 - r2_score: 0.0270 - root_mean_squared_error: 22.5314
# Epoch 7/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 487.3892 - mean_absolute_error: 19.6905 - mean_absolute_percentage_error: 33.6685 - r2_score: 0.0579 - root_mean_squared_error: 22.0766
# Epoch 8/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 460.9429 - mean_absolute_error: 19.0576 - mean_absolute_percentage_error: 36.5416 - r2_score: 0.1119 - root_mean_squared_error: 21.4690
# Epoch 9/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 377.7429 - mean_absolute_error: 17.2185 - mean_absolute_percentage_error: 32.3966 - r2_score: 0.2833 - root_mean_squared_error: 19.4208
# Epoch 10/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 136.2197 - mean_absolute_error: 9.4355 - mean_absolute_percentage_error: 20.3452 - r2_score: 0.7356 - root_mean_squared_error: 11.5886
# Epoch 11/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.7030 - mean_absolute_error: 2.8473 - mean_absolute_percentage_error: 8.0788 - r2_score: 0.9662 - root_mean_squared_error: 4.1718
# Epoch 12/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.9065 - mean_absolute_error: 1.2929 - mean_absolute_percentage_error: 3.4662 - r2_score: 0.9924 - root_mean_squared_error: 1.9757
# Epoch 13/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0167 - mean_absolute_error: 1.1294 - mean_absolute_percentage_error: 4.3079 - r2_score: 0.9942 - root_mean_squared_error: 1.7325
# Epoch 14/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5014 - mean_absolute_error: 1.0712 - mean_absolute_percentage_error: 2.5335 - r2_score: 0.9952 - root_mean_squared_error: 1.5799
# Epoch 15/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.3389 - mean_absolute_error: 1.2474 - mean_absolute_percentage_error: 3.2865 - r2_score: 0.9935 - root_mean_squared_error: 1.8221
# Epoch 16/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.3940 - mean_absolute_error: 1.0973 - mean_absolute_percentage_error: 1.9854 - r2_score: 0.9954 - root_mean_squared_error: 1.5463
# Epoch 17/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4208 - mean_absolute_error: 1.0754 - mean_absolute_percentage_error: 3.4995 - r2_score: 0.9954 - root_mean_squared_error: 1.5516
# Epoch 18/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8185 - mean_absolute_error: 1.0723 - mean_absolute_percentage_error: 2.3916 - r2_score: 0.9946 - root_mean_squared_error: 1.6740
# Epoch 19/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2813 - mean_absolute_error: 1.0322 - mean_absolute_percentage_error: 3.0309 - r2_score: 0.9956 - root_mean_squared_error: 1.5097
# Epoch 20/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4577 - mean_absolute_error: 1.0955 - mean_absolute_percentage_error: 3.5865 - r2_score: 0.9952 - root_mean_squared_error: 1.5670
# Epoch 21/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2681 - mean_absolute_error: 1.0560 - mean_absolute_percentage_error: 1.9452 - r2_score: 0.9956 - root_mean_squared_error: 1.5036
# Epoch 22/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4976 - mean_absolute_error: 1.0654 - mean_absolute_percentage_error: 3.3826 - r2_score: 0.9952 - root_mean_squared_error: 1.5785
# Epoch 23/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2462 - mean_absolute_error: 1.0774 - mean_absolute_percentage_error: 2.2447 - r2_score: 0.9956 - root_mean_squared_error: 1.4976
# Epoch 24/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5213 - mean_absolute_error: 1.0526 - mean_absolute_percentage_error: 2.9065 - r2_score: 0.9951 - root_mean_squared_error: 1.5846
# Epoch 25/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4574 - mean_absolute_error: 1.0825 - mean_absolute_percentage_error: 4.8332 - r2_score: 0.9953 - root_mean_squared_error: 1.5662
# Epoch 26/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1877 - mean_absolute_error: 1.0429 - mean_absolute_percentage_error: 1.9230 - r2_score: 0.9958 - root_mean_squared_error: 1.4753
# Epoch 27/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.2776 - mean_absolute_error: 1.2697 - mean_absolute_percentage_error: 3.0083 - r2_score: 0.9937 - root_mean_squared_error: 1.8070
# Epoch 28/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1631 - mean_absolute_error: 1.3118 - mean_absolute_percentage_error: 2.2525 - r2_score: 0.9939 - root_mean_squared_error: 1.7768
# Epoch 29/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7577 - mean_absolute_error: 1.0849 - mean_absolute_percentage_error: 4.5460 - r2_score: 0.9947 - root_mean_squared_error: 1.6569
# Epoch 30/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7181 - mean_absolute_error: 1.1119 - mean_absolute_percentage_error: 4.0591 - r2_score: 0.9948 - root_mean_squared_error: 1.6456
# Epoch 31/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7393 - mean_absolute_error: 1.0683 - mean_absolute_percentage_error: 7.6451 - r2_score: 0.9948 - root_mean_squared_error: 1.6492
# Epoch 32/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6023 - mean_absolute_error: 1.1254 - mean_absolute_percentage_error: 3.3045 - r2_score: 0.9950 - root_mean_squared_error: 1.6121
# Epoch 33/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4016 - mean_absolute_error: 1.0973 - mean_absolute_percentage_error: 2.7007 - r2_score: 0.9954 - root_mean_squared_error: 1.5473
# Epoch 34/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2456 - mean_absolute_error: 1.0826 - mean_absolute_percentage_error: 2.3765 - r2_score: 0.9958 - root_mean_squared_error: 1.4975
# Epoch 35/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7548 - mean_absolute_error: 1.1798 - mean_absolute_percentage_error: 3.5527 - r2_score: 0.9948 - root_mean_squared_error: 1.6586
# Epoch 36/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4518 - mean_absolute_error: 1.0680 - mean_absolute_percentage_error: 2.2356 - r2_score: 0.9953 - root_mean_squared_error: 1.5652
# Epoch 37/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4313 - mean_absolute_error: 1.0445 - mean_absolute_percentage_error: 4.1237 - r2_score: 0.9955 - root_mean_squared_error: 1.5574
# Epoch 38/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7197 - mean_absolute_error: 1.0782 - mean_absolute_percentage_error: 3.5777 - r2_score: 0.9948 - root_mean_squared_error: 1.6367
# Epoch 39/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2609 - mean_absolute_error: 1.0615 - mean_absolute_percentage_error: 2.9016 - r2_score: 0.9956 - root_mean_squared_error: 1.5012
# Epoch 40/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8975 - mean_absolute_error: 1.1636 - mean_absolute_percentage_error: 3.6014 - r2_score: 0.9945 - root_mean_squared_error: 1.6967
# Epoch 41/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0795 - mean_absolute_error: 1.3107 - mean_absolute_percentage_error: 4.0533 - r2_score: 0.9940 - root_mean_squared_error: 1.7534
# Epoch 42/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5925 - mean_absolute_error: 1.1089 - mean_absolute_percentage_error: 4.6406 - r2_score: 0.9950 - root_mean_squared_error: 1.6093
# Epoch 43/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5906 - mean_absolute_error: 1.0937 - mean_absolute_percentage_error: 2.1534 - r2_score: 0.9949 - root_mean_squared_error: 1.6053
# Epoch 44/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7315 - mean_absolute_error: 1.1189 - mean_absolute_percentage_error: 3.7137 - r2_score: 0.9948 - root_mean_squared_error: 1.6499
# Epoch 45/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5343 - mean_absolute_error: 1.0764 - mean_absolute_percentage_error: 2.1748 - r2_score: 0.9951 - root_mean_squared_error: 1.5911
# Epoch 46/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1595 - mean_absolute_error: 1.0246 - mean_absolute_percentage_error: 2.8881 - r2_score: 0.9959 - root_mean_squared_error: 1.4677
# Epoch 47/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6604 - mean_absolute_error: 1.1695 - mean_absolute_percentage_error: 2.8425 - r2_score: 0.9949 - root_mean_squared_error: 1.6293
# Epoch 48/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2956 - mean_absolute_error: 1.0674 - mean_absolute_percentage_error: 2.0660 - r2_score: 0.9956 - root_mean_squared_error: 1.5143
# Epoch 49/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8406 - mean_absolute_error: 1.1192 - mean_absolute_percentage_error: 7.6138 - r2_score: 0.9946 - root_mean_squared_error: 1.6801
# Epoch 50/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2668 - mean_absolute_error: 1.0298 - mean_absolute_percentage_error: 3.1066 - r2_score: 0.9957 - root_mean_squared_error: 1.4989

# %%
y_pred = gruModel.predict(x_test, verbose=0)
train_indices = np.arange(len(y_train))
test_indices = np.arange(len(y_train), len(y_train) + len(y_test))
pred_indices = np.arange(len(y_train), len(y_train) + len(y_pred))
plt.figure(figsize=(10, 6))
plt.plot(train_indices, y_train, label='train')
plt.plot(test_indices, y_test, label='test')
plt.plot(pred_indices, y_pred, label='prediction')
plt.title('GRU: Training and Testing and Predicting data for CL=F Price')
plt.legend(loc='lower right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### ◆ LSTM Model

# %%
lstmModel = Sequential([
    LSTM(units['LSTM'], return_sequences=True, input_shape=input_shape),
    LSTM(units['LSTM'], return_sequences=False),
    Dense(25, activation='relu'),
    Dense(1)
    ])
lstmModel.compile(optimizer=lstmOptimizer, loss='mse', metrics=metrics)

# %%
lstmModel.fit(x_train, y_train, batch_size=batch_size, epochs=epoches)
# Out:
# Epoch 1/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 4634.9961 - mean_absolute_error: 20.0773 - mean_absolute_percentage_error: 29.6007 - r2_score: -1.6751 - root_mean_squared_error: 36.4914
# Epoch 2/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 505.0977 - mean_absolute_error: 19.6461 - mean_absolute_percentage_error: 37.6848 - r2_score: 0.0219 - root_mean_squared_error: 22.4695
# Epoch 3/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 376.2590 - mean_absolute_error: 17.2318 - mean_absolute_percentage_error: 34.3417 - r2_score: 0.2905 - root_mean_squared_error: 19.3827
# Epoch 4/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 190.0028 - mean_absolute_error: 12.1956 - mean_absolute_percentage_error: 34.3126 - r2_score: 0.6357 - root_mean_squared_error: 13.7507
# Epoch 5/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 29.7501 - mean_absolute_error: 4.4029 - mean_absolute_percentage_error: 6.8605 - r2_score: 0.9431 - root_mean_squared_error: 5.3903
# Epoch 6/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.1646 - mean_absolute_error: 2.3473 - mean_absolute_percentage_error: 5.2462 - r2_score: 0.9824 - root_mean_squared_error: 3.0271
# Epoch 7/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.8863 - mean_absolute_error: 2.1542 - mean_absolute_percentage_error: 4.5590 - r2_score: 0.9850 - root_mean_squared_error: 2.8072
# Epoch 8/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.2443 - mean_absolute_error: 1.8956 - mean_absolute_percentage_error: 3.6127 - r2_score: 0.9879 - root_mean_squared_error: 2.4972
# Epoch 9/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.9080 - mean_absolute_error: 1.7786 - mean_absolute_percentage_error: 3.6902 - r2_score: 0.9887 - root_mean_squared_error: 2.4282
# Epoch 10/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.5281 - mean_absolute_error: 1.5867 - mean_absolute_percentage_error: 4.5781 - r2_score: 0.9911 - root_mean_squared_error: 2.1265
# Epoch 11/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.0607 - mean_absolute_error: 1.6176 - mean_absolute_percentage_error: 3.8141 - r2_score: 0.9903 - root_mean_squared_error: 2.2464
# Epoch 12/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2461 - mean_absolute_error: 1.4579 - mean_absolute_percentage_error: 3.2969 - r2_score: 0.9917 - root_mean_squared_error: 2.0576
# Epoch 13/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.1780 - mean_absolute_error: 1.3456 - mean_absolute_percentage_error: 3.9256 - r2_score: 0.9919 - root_mean_squared_error: 2.0323
# Epoch 14/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0985 - mean_absolute_error: 1.2616 - mean_absolute_percentage_error: 2.3827 - r2_score: 0.9939 - root_mean_squared_error: 1.7585
# Epoch 15/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1255 - mean_absolute_error: 1.2492 - mean_absolute_percentage_error: 2.8263 - r2_score: 0.9939 - root_mean_squared_error: 1.7669
# Epoch 16/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6768 - mean_absolute_error: 1.1403 - mean_absolute_percentage_error: 2.4307 - r2_score: 0.9948 - root_mean_squared_error: 1.6332
# Epoch 17/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5106 - mean_absolute_error: 1.1210 - mean_absolute_percentage_error: 3.1079 - r2_score: 0.9952 - root_mean_squared_error: 1.5841
# Epoch 18/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2238 - mean_absolute_error: 1.0656 - mean_absolute_percentage_error: 2.2167 - r2_score: 0.9958 - root_mean_squared_error: 1.4894
# Epoch 19/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6007 - mean_absolute_error: 1.0686 - mean_absolute_percentage_error: 2.4234 - r2_score: 0.9951 - root_mean_squared_error: 1.6102
# Epoch 20/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5178 - mean_absolute_error: 1.0535 - mean_absolute_percentage_error: 3.9126 - r2_score: 0.9951 - root_mean_squared_error: 1.5820
# Epoch 21/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4121 - mean_absolute_error: 1.0206 - mean_absolute_percentage_error: 1.7962 - r2_score: 0.9954 - root_mean_squared_error: 1.5485
# Epoch 22/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0537 - mean_absolute_error: 1.0472 - mean_absolute_percentage_error: 4.9743 - r2_score: 0.9944 - root_mean_squared_error: 1.7260
# Epoch 23/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2007 - mean_absolute_error: 1.0403 - mean_absolute_percentage_error: 2.5403 - r2_score: 0.9958 - root_mean_squared_error: 1.4824
# Epoch 24/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.5701 - mean_absolute_error: 1.0118 - mean_absolute_percentage_error: 3.8844 - r2_score: 0.9952 - root_mean_squared_error: 1.5996
# Epoch 25/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7527 - mean_absolute_error: 1.1863 - mean_absolute_percentage_error: 3.8608 - r2_score: 0.9946 - root_mean_squared_error: 1.6572
# Epoch 26/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.4370 - mean_absolute_error: 1.2046 - mean_absolute_percentage_error: 4.4034 - r2_score: 0.9933 - root_mean_squared_error: 1.8395
# Epoch 27/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1913 - mean_absolute_error: 0.9856 - mean_absolute_percentage_error: 3.2924 - r2_score: 0.9958 - root_mean_squared_error: 1.4755
# Epoch 28/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2628 - mean_absolute_error: 1.0319 - mean_absolute_percentage_error: 2.6939 - r2_score: 0.9956 - root_mean_squared_error: 1.5012
# Epoch 29/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1726 - mean_absolute_error: 0.9748 - mean_absolute_percentage_error: 2.4473 - r2_score: 0.9958 - root_mean_squared_error: 1.4708
# Epoch 30/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0093 - mean_absolute_error: 0.9779 - mean_absolute_percentage_error: 2.0592 - r2_score: 0.9961 - root_mean_squared_error: 1.4153
# Epoch 31/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.3675 - mean_absolute_error: 1.0483 - mean_absolute_percentage_error: 1.9405 - r2_score: 0.9955 - root_mean_squared_error: 1.5377
# Epoch 32/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2040 - mean_absolute_error: 1.0186 - mean_absolute_percentage_error: 2.6690 - r2_score: 0.9958 - root_mean_squared_error: 1.4830
# Epoch 33/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4035 - mean_absolute_error: 1.0130 - mean_absolute_percentage_error: 2.8007 - r2_score: 0.9953 - root_mean_squared_error: 1.5473
# Epoch 34/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0634 - mean_absolute_error: 1.0144 - mean_absolute_percentage_error: 1.7825 - r2_score: 0.9961 - root_mean_squared_error: 1.4342
# Epoch 35/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5770 - mean_absolute_error: 1.1098 - mean_absolute_percentage_error: 1.9925 - r2_score: 0.9949 - root_mean_squared_error: 1.6031
# Epoch 36/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0543 - mean_absolute_error: 0.9938 - mean_absolute_percentage_error: 2.6427 - r2_score: 0.9960 - root_mean_squared_error: 1.4310
# Epoch 37/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5130 - mean_absolute_error: 1.0423 - mean_absolute_percentage_error: 2.5227 - r2_score: 0.9951 - root_mean_squared_error: 1.5815
# Epoch 38/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5789 - mean_absolute_error: 0.9916 - mean_absolute_percentage_error: 4.6114 - r2_score: 0.9951 - root_mean_squared_error: 1.6015
# Epoch 39/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8130 - mean_absolute_error: 1.0470 - mean_absolute_percentage_error: 4.6813 - r2_score: 0.9946 - root_mean_squared_error: 1.6663
# Epoch 40/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2607 - mean_absolute_error: 0.9990 - mean_absolute_percentage_error: 7.2549 - r2_score: 0.9958 - root_mean_squared_error: 1.4953
# Epoch 41/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5301 - mean_absolute_error: 1.0869 - mean_absolute_percentage_error: 3.3991 - r2_score: 0.9951 - root_mean_squared_error: 1.5824
# Epoch 42/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7512 - mean_absolute_error: 1.0380 - mean_absolute_percentage_error: 2.7121 - r2_score: 0.9948 - root_mean_squared_error: 1.6446
# Epoch 43/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0299 - mean_absolute_error: 0.9854 - mean_absolute_percentage_error: 1.7696 - r2_score: 0.9961 - root_mean_squared_error: 1.4219
# Epoch 44/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6943 - mean_absolute_error: 1.0324 - mean_absolute_percentage_error: 3.5185 - r2_score: 0.9948 - root_mean_squared_error: 1.6354
# Epoch 45/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1798 - mean_absolute_error: 1.0750 - mean_absolute_percentage_error: 1.8447 - r2_score: 0.9958 - root_mean_squared_error: 1.4696
# Epoch 46/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.3677 - mean_absolute_error: 1.0157 - mean_absolute_percentage_error: 3.7576 - r2_score: 0.9955 - root_mean_squared_error: 1.5364
# Epoch 47/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1582 - mean_absolute_error: 0.9643 - mean_absolute_percentage_error: 4.2603 - r2_score: 0.9958 - root_mean_squared_error: 1.4663
# Epoch 48/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2175 - mean_absolute_error: 1.0459 - mean_absolute_percentage_error: 2.5429 - r2_score: 0.9958 - root_mean_squared_error: 1.4826
# Epoch 49/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4453 - mean_absolute_error: 1.0287 - mean_absolute_percentage_error: 3.0054 - r2_score: 0.9953 - root_mean_squared_error: 1.5617
# Epoch 50/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5331 - mean_absolute_error: 1.0724 - mean_absolute_percentage_error: 3.9815 - r2_score: 0.9952 - root_mean_squared_error: 1.5897

# %%
y_pred = lstmModel.predict(x_test, verbose=0)
train_indices = np.arange(len(y_train))
test_indices = np.arange(len(y_train), len(y_train) + len(y_test))
pred_indices = np.arange(len(y_train), len(y_train) + len(y_pred))
plt.figure(figsize=(10, 6))
plt.plot(train_indices, y_train, label='train')
plt.plot(test_indices, y_test, label='test')
plt.plot(pred_indices, y_pred, label='prediction')
plt.title('LSTM: Training and Testing and Predicting data for CL=F Price')
plt.legend(loc='lower right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### ◆ Bi-LSTM Model

# %%
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))

# %%
bilstmModel = Sequential([
    Bidirectional(LSTM(units['Bi-LSTM'], return_sequences=True, input_shape=input_shape)),
    Bidirectional(LSTM(units['Bi-LSTM'], return_sequences=False)),
    Dense(25, activation='relu'),
    Dense(1)
    ])
bilstmModel.compile(optimizer=bilstmOptimizer, loss='mse', metrics=metrics)

# %%
bilstmModel.fit(x_train, y_train, batch_size=batch_size, epochs=epoches)
# Out:
# Epoch 1/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 8s 27ms/step - loss: 3269.7893 - mean_absolute_error: 14.4839 - mean_absolute_percentage_error: 22.5124 - r2_score: -0.6689 - root_mean_squared_error: 29.1761
# Epoch 2/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 252.2168 - mean_absolute_error: 13.9599 - mean_absolute_percentage_error: 30.5329 - r2_score: 0.5301 - root_mean_squared_error: 15.7957
# Epoch 3/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 17.8716 - mean_absolute_error: 3.2638 - mean_absolute_percentage_error: 5.4556 - r2_score: 0.9653 - root_mean_squared_error: 4.1927
# Epoch 4/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 8.4528 - mean_absolute_error: 2.2222 - mean_absolute_percentage_error: 5.3994 - r2_score: 0.9842 - root_mean_squared_error: 2.9061
# Epoch 5/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 6.3566 - mean_absolute_error: 1.7906 - mean_absolute_percentage_error: 4.2342 - r2_score: 0.9878 - root_mean_squared_error: 2.5193
# Epoch 6/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.3594 - mean_absolute_error: 1.4576 - mean_absolute_percentage_error: 2.7650 - r2_score: 0.9916 - root_mean_squared_error: 2.0855
# Epoch 7/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.5080 - mean_absolute_error: 1.1546 - mean_absolute_percentage_error: 4.4217 - r2_score: 0.9933 - root_mean_squared_error: 1.8563
# Epoch 8/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.2651 - mean_absolute_error: 0.9673 - mean_absolute_percentage_error: 5.1013 - r2_score: 0.9957 - root_mean_squared_error: 1.4989
# Epoch 9/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.8831 - mean_absolute_error: 0.8935 - mean_absolute_percentage_error: 2.2102 - r2_score: 0.9963 - root_mean_squared_error: 1.3689
# Epoch 10/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.9596 - mean_absolute_error: 0.9237 - mean_absolute_percentage_error: 2.2294 - r2_score: 0.9963 - root_mean_squared_error: 1.3974
# Epoch 11/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.9992 - mean_absolute_error: 0.9413 - mean_absolute_percentage_error: 3.5818 - r2_score: 0.9962 - root_mean_squared_error: 1.4114
# Epoch 12/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.9013 - mean_absolute_error: 0.8858 - mean_absolute_percentage_error: 2.2693 - r2_score: 0.9963 - root_mean_squared_error: 1.3760
# Epoch 13/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.7273 - mean_absolute_error: 0.8831 - mean_absolute_percentage_error: 1.8898 - r2_score: 0.9966 - root_mean_squared_error: 1.3117
# Epoch 14/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.7749 - mean_absolute_error: 0.8989 - mean_absolute_percentage_error: 2.7252 - r2_score: 0.9966 - root_mean_squared_error: 1.3288
# Epoch 15/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.1313 - mean_absolute_error: 0.9264 - mean_absolute_percentage_error: 3.4988 - r2_score: 0.9960 - root_mean_squared_error: 1.4557
# Epoch 16/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.6901 - mean_absolute_error: 0.8521 - mean_absolute_percentage_error: 1.9501 - r2_score: 0.9967 - root_mean_squared_error: 1.2949
# Epoch 17/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.1459 - mean_absolute_error: 0.8596 - mean_absolute_percentage_error: 3.1098 - r2_score: 0.9960 - root_mean_squared_error: 1.4527
# Epoch 18/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.8186 - mean_absolute_error: 0.9019 - mean_absolute_percentage_error: 4.8071 - r2_score: 0.9965 - root_mean_squared_error: 1.3448
# Epoch 19/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.1538 - mean_absolute_error: 0.8901 - mean_absolute_percentage_error: 3.7159 - r2_score: 0.9958 - root_mean_squared_error: 1.4567
# Epoch 20/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.5164 - mean_absolute_error: 0.9140 - mean_absolute_percentage_error: 2.3717 - r2_score: 0.9952 - root_mean_squared_error: 1.5617
# Epoch 21/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.2926 - mean_absolute_error: 0.9185 - mean_absolute_percentage_error: 3.3757 - r2_score: 0.9956 - root_mean_squared_error: 1.5079
# Epoch 22/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.6323 - mean_absolute_error: 0.9130 - mean_absolute_percentage_error: 1.6235 - r2_score: 0.9968 - root_mean_squared_error: 1.2767
# Epoch 23/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.8637 - mean_absolute_error: 0.8565 - mean_absolute_percentage_error: 2.2544 - r2_score: 0.9964 - root_mean_squared_error: 1.3603
# Epoch 24/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.6136 - mean_absolute_error: 0.8243 - mean_absolute_percentage_error: 4.0679 - r2_score: 0.9969 - root_mean_squared_error: 1.2679
# Epoch 25/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.1294 - mean_absolute_error: 0.9774 - mean_absolute_percentage_error: 4.1082 - r2_score: 0.9959 - root_mean_squared_error: 1.4558
# Epoch 26/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.4790 - mean_absolute_error: 1.1688 - mean_absolute_percentage_error: 2.1229 - r2_score: 0.9952 - root_mean_squared_error: 1.5710
# Epoch 27/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.1998 - mean_absolute_error: 0.9389 - mean_absolute_percentage_error: 2.2480 - r2_score: 0.9958 - root_mean_squared_error: 1.4796
# Epoch 28/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.0202 - mean_absolute_error: 0.9480 - mean_absolute_percentage_error: 3.0612 - r2_score: 0.9961 - root_mean_squared_error: 1.4185
# Epoch 29/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.0817 - mean_absolute_error: 0.9889 - mean_absolute_percentage_error: 2.1119 - r2_score: 0.9960 - root_mean_squared_error: 1.4414
# Epoch 30/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.8906 - mean_absolute_error: 0.9858 - mean_absolute_percentage_error: 2.5781 - r2_score: 0.9964 - root_mean_squared_error: 1.3735
# Epoch 31/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.0788 - mean_absolute_error: 1.0613 - mean_absolute_percentage_error: 1.9720 - r2_score: 0.9960 - root_mean_squared_error: 1.4408
# Epoch 32/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.7711 - mean_absolute_error: 0.8791 - mean_absolute_percentage_error: 2.0847 - r2_score: 0.9966 - root_mean_squared_error: 1.3296
# Epoch 33/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.5925 - mean_absolute_error: 0.8286 - mean_absolute_percentage_error: 2.8305 - r2_score: 0.9969 - root_mean_squared_error: 1.2583
# Epoch 34/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.0747 - mean_absolute_error: 0.9835 - mean_absolute_percentage_error: 2.2182 - r2_score: 0.9961 - root_mean_squared_error: 1.4361
# Epoch 35/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.7513 - mean_absolute_error: 0.8623 - mean_absolute_percentage_error: 2.9219 - r2_score: 0.9967 - root_mean_squared_error: 1.3201
# Epoch 36/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.6893 - mean_absolute_error: 0.8886 - mean_absolute_percentage_error: 2.3515 - r2_score: 0.9967 - root_mean_squared_error: 1.2987
# Epoch 37/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.3308 - mean_absolute_error: 1.0341 - mean_absolute_percentage_error: 2.8816 - r2_score: 0.9956 - root_mean_squared_error: 1.5149
# Epoch 38/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.6361 - mean_absolute_error: 0.8351 - mean_absolute_percentage_error: 3.6522 - r2_score: 0.9969 - root_mean_squared_error: 1.2776
# Epoch 39/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.1323 - mean_absolute_error: 0.9017 - mean_absolute_percentage_error: 5.7038 - r2_score: 0.9959 - root_mean_squared_error: 1.4568
# Epoch 40/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.6717 - mean_absolute_error: 0.8324 - mean_absolute_percentage_error: 1.6720 - r2_score: 0.9968 - root_mean_squared_error: 1.2905
# Epoch 41/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.9847 - mean_absolute_error: 0.8631 - mean_absolute_percentage_error: 3.5132 - r2_score: 0.9963 - root_mean_squared_error: 1.4041
# Epoch 42/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.0755 - mean_absolute_error: 1.0091 - mean_absolute_percentage_error: 1.7518 - r2_score: 0.9960 - root_mean_squared_error: 1.4376
# Epoch 43/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.4617 - mean_absolute_error: 0.8175 - mean_absolute_percentage_error: 1.4589 - r2_score: 0.9972 - root_mean_squared_error: 1.2073
# Epoch 44/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.7935 - mean_absolute_error: 0.9107 - mean_absolute_percentage_error: 1.8361 - r2_score: 0.9965 - root_mean_squared_error: 1.3368
# Epoch 45/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.9215 - mean_absolute_error: 0.9340 - mean_absolute_percentage_error: 3.1296 - r2_score: 0.9963 - root_mean_squared_error: 1.3845
# Epoch 46/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.2683 - mean_absolute_error: 1.0975 - mean_absolute_percentage_error: 4.3172 - r2_score: 0.9957 - root_mean_squared_error: 1.5028
# Epoch 47/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.2705 - mean_absolute_error: 0.9330 - mean_absolute_percentage_error: 2.4914 - r2_score: 0.9956 - root_mean_squared_error: 1.4941
# Epoch 48/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.3974 - mean_absolute_error: 1.1753 - mean_absolute_percentage_error: 2.9360 - r2_score: 0.9955 - root_mean_squared_error: 1.5465
# Epoch 49/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.3943 - mean_absolute_error: 0.9839 - mean_absolute_percentage_error: 2.6403 - r2_score: 0.9954 - root_mean_squared_error: 1.5261
# Epoch 50/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.5631 - mean_absolute_error: 0.8425 - mean_absolute_percentage_error: 1.8595 - r2_score: 0.9969 - root_mean_squared_error: 1.2470

# %%
y_pred = bilstmModel.predict(x_test, verbose=0)
train_indices = np.arange(len(y_train))
test_indices = np.arange(len(y_train), len(y_train) + len(y_test))
pred_indices = np.arange(len(y_train), len(y_train) + len(y_pred))
plt.figure(figsize=(10, 6))
plt.plot(train_indices, y_train, label='train')
plt.plot(test_indices, y_test, label='test')
plt.plot(pred_indices, y_pred, label='prediction')
plt.title('Bi-LSTM: Training and Testing and Predicting data for CL=F Price')
plt.legend(loc='lower right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# <a name="4"></a>
# ## 4 - ARIMA Model

# %% [markdown]
# ### ◆ Getting Best Order

# %%
model = auto_arima(y_train, seasonal=True, stepwise=True, trace=True, suppress_warnings=True, n_jobs=-1)
print(model.summary())
best_order = model.order
print(f"Best ARIMA order (p, d, q): {best_order}")
# Out:
# /opt/conda/lib/python3.10/site-packages/pmdarima/arima/_validation.py:76: UserWarning: stepwise model cannot be fit in parallel (n_jobs=1). Falling back to stepwise parameter search.
#   warnings.warn('stepwise model cannot be fit in parallel (n_jobs=%i). '
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=12119.414, Time=1.24 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=12219.268, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=12212.693, Time=0.12 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=12209.999, Time=0.16 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=12217.603, Time=0.05 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=12135.106, Time=0.54 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=12124.445, Time=0.64 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=12117.415, Time=1.50 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=12115.680, Time=0.69 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=12113.723, Time=0.33 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=12152.076, Time=0.30 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=12115.686, Time=0.65 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=12117.683, Time=0.75 sec
#  ARIMA(3,1,0)(0,0,0)[0]             : AIC=12112.110, Time=0.32 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=12150.552, Time=0.16 sec
#  ARIMA(4,1,0)(0,0,0)[0]             : AIC=12114.071, Time=0.41 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=12114.064, Time=0.66 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=12122.890, Time=0.37 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : AIC=12116.067, Time=0.50 sec
#
# Best model:  ARIMA(3,1,0)(0,0,0)[0]
# Total fit time: 9.462 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3822
# Model:               SARIMAX(3, 1, 0)   Log Likelihood               -6052.055
# Date:                Thu, 19 Dec 2024   AIC                          12112.110
# Time:                        14:56:49   BIC                          12137.103
# Sample:                             0   HQIC                         12120.990
#                                - 3822
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0402      0.004    -11.129      0.000      -0.047      -0.033
# ar.L2         -0.1219      0.006    -21.725      0.000      -0.133      -0.111
# ar.L3          0.1026      0.007     14.751      0.000       0.089       0.116
# sigma2         1.3908      0.008    164.860      0.000       1.374       1.407
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):            973563.06
# Prob(Q):                              0.98   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.44   Skew:                            -1.46
# Prob(H) (two-sided):                  0.00   Kurtosis:                        81.14
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Best ARIMA order (p, d, q): (3, 1, 0)

# %% [markdown]
# ### ◆ ARIMA Model with Best Order

# %%
arimaModel = ARIMA(y_train, order=best_order)
model_fit = arimaModel.fit()
y_pred = model_fit.forecast(steps=len(y_test))
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)

print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"R-squared (R2): {r2:.2f}")
print(f"Mean Absolute Percentage Error (MAPE): {mape * 100:.2f}%")
# Out:
# Mean Squared Error (MSE): 1465.57
# Mean Absolute Error (MAE): 34.42
# Root Mean Squared Error (RMSE): 38.28
# R-squared (R2): -4.07
# Mean Absolute Percentage Error (MAPE): 42.72%

# %% [markdown]
# ---
